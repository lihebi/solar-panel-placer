# %%
from place import place_solar_panel

# %%
from draw import draw

# %%
polygon = [(1,3), (2,6), (8,5), (8,4)]

# %%
panels = place_solar_panel(polygon, 2, 1)

# %%
draw(polygon)

# %%
draw(polygon, panels)
